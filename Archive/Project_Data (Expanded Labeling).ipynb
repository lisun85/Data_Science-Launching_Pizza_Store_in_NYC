# %%
import pandas as pd

# %%
a_Oct15 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161015.txt")
b_Oct08 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161008.txt")
c_Oct01 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161001.txt")

d_Sep24 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160924.txt")
e_Sep17 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160917.txt")
f_Sep10 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160910.txt")
g_Sep03 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160903.txt")

h_Aug27 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160827.txt")
i_Aug20 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160820.txt")
j_Aug13 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160813.txt")
k_Aug06 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160806.txt")

l_Jul30 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160730.txt")
m_Jul23 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160723.txt")
n_Jul16 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160716.txt")
o_Jul09 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160709.txt")

# %%
df = pd.concat([a])

o_Jul09.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 193059  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/08/2016
# 193060  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/08/2016
# 193061  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/08/2016
# 193062  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/08/2016
# 193063  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/08/2016
#
#             TIME     DESC  ENTRIES  \
# 193059  05:00:00  REGULAR     5554
# 193060  09:00:00  REGULAR     5554
# 193061  13:00:00  REGULAR     5554
# 193062  17:00:00  REGULAR     5554
# 193063  21:00:00  REGULAR     5554
#
#         EXITS
# 193059                                                251
# 193060                                                251
# 193061                                                251
# 193062                                                251
# ...

# %%
n_Jul16
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/09/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/09/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/09/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/09/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/09/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193866  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/15/2016
# 193867  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/15/2016
# 193868  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/15/2016
# 193869  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/15/2016
# 193870  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/15/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
m_Jul23
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/16/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/16/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/16/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/16/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/16/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193330  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/22/2016
# 193331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/22/2016
# 193332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/22/2016
# 193333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/22/2016
# 193334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/22/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
l_Jul30
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/23/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/23/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/23/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/23/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/23/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 191489  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/29/2016
# 191490  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/29/2016
# 191491  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/29/2016
# 191492  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/29/2016
# 191493  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  07/29/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
k_Aug06
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/30/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/30/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/30/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/30/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/30/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193382  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/05/2016
# 193383  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/05/2016
# 193384  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/05/2016
# 193385  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/05/2016
# 193386  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/05/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
j_Aug13
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  08/06/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  08/06/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  08/06/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  08/06/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  08/06/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193217  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/12/2016
# 193218  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/12/2016
# 193219  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/12/2016
# 193220  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/12/2016
# 193221  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/12/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
i_Aug20
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  08/13/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  08/13/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  08/13/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  08/13/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  08/13/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 190535  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/19/2016
# 190536  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/19/2016
# 190537  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/19/2016
# 190538  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/19/2016
# 190539  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/19/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
h_Aug27
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  08/20/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  08/20/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  08/20/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  08/20/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  08/20/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 191607  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/26/2016
# 191608  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/26/2016
# 191609  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/26/2016
# 191610  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/26/2016
# 191611  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/26/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
g_Sep03
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  08/27/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 193134  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/02/2016
# 193135  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/02/2016
# 193136  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/02/2016
# 193137  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/02/2016
# 193138  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/02/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
f_Sep10
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  09/03/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  09/03/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  09/03/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  09/03/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  09/03/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 194873  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/09/2016
# 194874  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/09/2016
# 194875  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/09/2016
# 194876  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/09/2016
# 194877  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/09/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
e_Sep17
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  09/10/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  09/10/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  09/10/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  09/10/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  09/10/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 192873  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192874  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192875  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192876  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
# 192877  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/16/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
d_Sep24
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  09/17/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  09/17/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  09/17/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  09/17/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  09/17/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 192673  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192674  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192675  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192676  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
# 192677  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/23/2016
#
#             TIME     DESC  ENTRIES  \
# ...
