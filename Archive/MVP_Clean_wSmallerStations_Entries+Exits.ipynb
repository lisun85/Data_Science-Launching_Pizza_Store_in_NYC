# %%
import pandas as pd

# %%
a = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161015.txt")
b = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161008.txt")
c = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_161001.txt")

d = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160924.txt")
e = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160917.txt")
f = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160910.txt")
g = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160903.txt")

h = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160827.txt")
i = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160820.txt")
j = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160813.txt")
k = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160806.txt")

l = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160730.txt")
m = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160723.txt")
n = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160716.txt")
o = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160709.txt")

# %%
#Concat datasets for 15 weeks
df = pd.concat([o,n,m,l,k,j,i,h,g,f,e,d,c,b,a])

df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 192296  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192297  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192298  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192299  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192300  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
#Data Cleaning - viewing all columns
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
#Declaring new variable and stripping all column names of spaces
df.columns = [column.strip() for column in df.columns]
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
#combining Entries and Exits to get total Foot_Traffic <=== this step is no longer needed here now, will do again later
df["Foot_Traffic"] = df.ENTRIES + df.EXITS
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 1        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 2        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 3        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# 4        A002  R051  02-00-00          59 ST   NQR456      BMT  07/02/2016
# ...       ...   ...       ...            ...      ...      ...         ...
# 192296  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192297  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192298  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192299  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
# 192300  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/14/2016
#
#             TIME     DESC  ENTRIES    EXITS  Foot_Traffic
# ...

# %%
df.DATE.value_counts().sort_index().reset_index()
# Out:
#           index   DATE
# 0    07/02/2016  27448
# 1    07/03/2016  27321
# 2    07/04/2016  27433
# 3    07/05/2016  28268
# 4    07/06/2016  27319
# ..          ...    ...
# 100  10/10/2016  27795
# 101  10/11/2016  27336
# 102  10/12/2016  27553
# 103  10/13/2016  27479
# 104  10/14/2016  27412
#
# [105 rows x 2 columns]

# %%
#Add Date_Time Column
import datetime

# %%
df['Date_Time'] = pd.to_datetime(df.DATE+" "+df.TIME)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2893032 entries, 0 to 192300
# Data columns (total 13 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   C/A           object
#  1   UNIT          object
#  2   SCP           object
#  3   STATION       object
#  4   LINENAME      object
#  5   DIVISION      object
#  6   DATE          object
#  7   TIME          object
#  8   DESC          object
#  9   ENTRIES       int64
#  10  EXITS         int64
#  11  Foot_Traffic  int64
#  12  Date_Time     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 309.0+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  16:00:00
#
#       DESC  ENTRIES    EXITS  Foot_Traffic           Date_Time
# 0  REGULAR  5722990  1941763       7664753 2016-07-02 00:00:00
# 1  REGULAR  5723019  1941767       7664786 2016-07-02 04:00:00
# 2  REGULAR  5723041  1941799       7664840 2016-07-02 08:00:00
# 3  REGULAR  5723135  1941893       7665028 2016-07-02 12:00:00
# 4  REGULAR  5723334  1941943       7665277 2016-07-02 16:00:00

# %%
#Eliminating Duplicates
mask = ((df["C/A"]=='A002') &
        (df["UNIT"]=='R051') &
        (df["SCP"]=='02-00-00') &
        (df["STATION"]=='59 ST')
       )

df[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  07/02/2016  16:00:00
#
#       DESC  ENTRIES    EXITS  Foot_Traffic           Date_Time
# 0  REGULAR  5722990  1941763       7664753 2016-07-02 00:00:00
# 1  REGULAR  5723019  1941767       7664786 2016-07-02 04:00:00
# 2  REGULAR  5723041  1941799       7664840 2016-07-02 08:00:00
# 3  REGULAR  5723135  1941893       7665028 2016-07-02 12:00:00
# 4  REGULAR  5723334  1941943       7665277 2016-07-02 16:00:00

# %%
#Filtering out Stations for Pizza

df_pizza = df[(df["STATION"] == 'TIMES SQ-42 ST') |
                     (df["STATION"] == '34 ST-HERALD SQ')|
                     (df["STATION"] == '42 ST-BRYANT PK')|
                     (df["STATION"] == 'GRD CNTRL-42 ST')|
                     (df["STATION"] == '34 ST-PENN STA') |
                     (df["STATION"] == '14 ST-UNION SQ') |
                     (df["STATION"] == 'ASTOR PL') |
                     (df["STATION"] == '34 ST-HUDSON YD') |
                     (df["STATION"] == '23 ST') |
                     (df["STATION"] == '28 ST') |
                     (df["STATION"] == '33 ST')]

df_pizza
# Out:
#          C/A  UNIT       SCP          STATION     LINENAME DIVISION  \
# 2624    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2625    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2626    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2627    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2628    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# ...      ...   ...       ...              ...          ...      ...
# 180811  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180812  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180813  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180814  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180815  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
#
#               DATE      TIME     DESC  ENTRIES    EXITS  Foot_Traffic  \
# 2624    07/02/2016  00:00:00  REGULAR  5836319  6841252      12677571
# ...

# %%
#Check for Dups
(df_pizza.groupby(["C/A", "UNIT", "SCP", "STATION", "Date_Time"]).ENTRIES.count().reset_index().sort_values("ENTRIES", ascending = False))
# Out:
#          C/A  UNIT       SCP          STATION           Date_Time  ENTRIES
# 0       A021  R032  01-00-00   TIMES SQ-42 ST 2016-07-02 00:00:00        1
# 205057  R220  R160  01-00-00         ASTOR PL 2016-08-16 21:00:00        1
# 205055  R220  R160  01-00-00         ASTOR PL 2016-08-16 13:00:00        1
# 205054  R220  R160  01-00-00         ASTOR PL 2016-08-16 09:00:00        1
# 205053  R220  R160  01-00-00         ASTOR PL 2016-08-16 05:00:00        1
# ...      ...   ...       ...              ...                 ...      ...
# 102524  N504  R021  02-06-00  42 ST-BRYANT PK 2016-08-08 04:00:00        1
# 102523  N504  R021  02-06-00  42 ST-BRYANT PK 2016-08-08 00:00:00        1
# 102522  N504  R021  02-06-00  42 ST-BRYANT PK 2016-08-07 20:00:00        1
# 102521  N504  R021  02-06-00  42 ST-BRYANT PK 2016-08-07 16:00:00        1
# 307574  R550  R072  00-05-01  34 ST-HUDSON YD 2016-10-14 20:00:00        1
#
# [307575 rows x 6 columns]

# %%
#Drop Duplicates just to see if same row exists
df_pizza.head()
# Out:
#        C/A  UNIT       SCP         STATION     LINENAME DIVISION        DATE  \
# 2624  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237      BMT  07/02/2016
# 2625  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237      BMT  07/02/2016
# 2626  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237      BMT  07/02/2016
# 2627  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237      BMT  07/02/2016
# 2628  A021  R032  01-00-00  TIMES SQ-42 ST  ACENQRS1237      BMT  07/02/2016
#
#           TIME     DESC  ENTRIES    EXITS  Foot_Traffic           Date_Time
# 2624  00:00:00  REGULAR  5836319  6841252      12677571 2016-07-02 00:00:00
# 2625  04:00:00  REGULAR  5836397  6841294      12677691 2016-07-02 04:00:00
# 2626  08:00:00  REGULAR  5836454  6841408      12677862 2016-07-02 08:00:00
# 2627  12:00:00  REGULAR  5836602  6841837      12678439 2016-07-02 12:00:00
# 2628  16:00:00  REGULAR  5836826  6842315      12679141 2016-07-02 16:00:00

# %%
df2 = df_pizza.drop_duplicates(subset=['C/A', 'UNIT', "SCP", "STATION", "Date_Time"])
df2.shape
# Out:
# (307575, 13)

# %%
#No Duplicates in df_pizza
#Need to Drop Columns - Actual FT

df_pizza
# Out:
#          C/A  UNIT       SCP          STATION     LINENAME DIVISION  \
# 2624    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2625    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2626    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2627    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# 2628    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237      BMT
# ...      ...   ...       ...              ...          ...      ...
# 180811  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180812  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180813  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180814  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
# 180815  R550  R072  00-05-01  34 ST-HUDSON YD            7      IRT
#
#               DATE      TIME     DESC  ENTRIES    EXITS  Foot_Traffic  \
# 2624    07/02/2016  00:00:00  REGULAR  5836319  6841252      12677571
# ...

# %%
#CREATION OF PIZZA_DAILY
#maximum ENTRIES per day. Pizza_daily (newly created) is only ENTRIES, will create Exits later

pizza_daily = (df_pizza
                  .groupby(["C/A", "UNIT", "SCP", "STATION","DATE", "TIME"], as_index=False)
                  ['ENTRIES', 'EXITS'].last())

pizza_daily
# Out:
# <ipython-input-68-663c15bbae88>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pizza_daily = (df_pizza
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 0       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  00:00:00  5836319
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  08:00:00  5836454
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  12:00:00  5836602
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  16:00:00  5836826
# ...      ...   ...       ...              ...         ...       ...      ...
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
# 307571  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  08:00:00        1
# 307572  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  12:00:00        1
# ...

# %%
#Create two columns with shift(1)

pizza_daily[['PREV_DATE', 'PREV_ENTRIES', 'PREV_EXITS']] = (pizza_daily
                                                 .groupby(['C/A', 'UNIT', 'SCP', 'STATION'])['DATE', 'ENTRIES', 'EXITS']
                                                 .apply(lambda grp: grp.shift(1))
                                             )
pizza_daily.head()
# Out:
# <ipython-input-69-d241225b51be>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pizza_daily[['PREV_DATE', 'PREV_ENTRIES', 'PREV_EXITS']] = (pizza_daily
#     C/A  UNIT       SCP         STATION        DATE      TIME  ENTRIES  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  07/02/2016  00:00:00  5836319
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  07/02/2016  08:00:00  5836454
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  07/02/2016  12:00:00  5836602
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  07/02/2016  16:00:00  5836826
#
#      EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 0  6841252         NaN           NaN         NaN
# 1  6841294  07/02/2016     5836319.0   6841252.0
# 2  6841408  07/02/2016     5836397.0   6841294.0
# 3  6841837  07/02/2016     5836454.0   6841408.0
# 4  6842315  07/02/2016     5836602.0   6841837.0

# %%
pizza_daily.tail()
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
# 307571  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  08:00:00        1
# 307572  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  12:00:00        1
# 307573  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  16:00:00        1
# 307574  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  20:00:00        1
#
#         EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 307570    186  10/14/2016           1.0       186.0
# 307571    186  10/14/2016           1.0       186.0
# 307572    186  10/14/2016           1.0       186.0
# 307573    186  10/14/2016           1.0       186.0
# 307574    186  10/14/2016           1.0       186.0

# %%
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 0       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  00:00:00  5836319
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  08:00:00  5836454
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  12:00:00  5836602
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  16:00:00  5836826
# ...      ...   ...       ...              ...         ...       ...      ...
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
# 307571  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  08:00:00        1
# 307572  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  12:00:00        1
# 307573  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  16:00:00        1
# 307574  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  20:00:00        1
#
# ...

# %%
#drop na for PREV_DATE column
pizza_daily.dropna(subset=["PREV_DATE"], axis = 0, inplace=True)
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  08:00:00  5836454
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  12:00:00  5836602
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  16:00:00  5836826
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  20:00:00  5837134
# ...      ...   ...       ...              ...         ...       ...      ...
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
# 307571  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  08:00:00        1
# 307572  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  12:00:00        1
# 307573  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  16:00:00        1
# 307574  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  20:00:00        1
#
# ...

# %%
#Interlude:Reverse Entries
pizza_daily[pizza_daily['ENTRIES']< pizza_daily['PREV_ENTRIES']]
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  \
# 12145   A025  R023  01-03-02  34 ST-HERALD SQ  07/02/2016  04:00:00
# 12146   A025  R023  01-03-02  34 ST-HERALD SQ  07/02/2016  08:00:00
# 12147   A025  R023  01-03-02  34 ST-HERALD SQ  07/02/2016  12:00:00
# 12148   A025  R023  01-03-02  34 ST-HERALD SQ  07/02/2016  16:00:00
# 12149   A025  R023  01-03-02  34 ST-HERALD SQ  07/02/2016  20:00:00
# ...      ...   ...       ...              ...         ...       ...
# 287567  R240  R047  00-03-00  GRD CNTRL-42 ST  09/19/2016  13:00:00
# 298820  R550  R072  00-03-00  34 ST-HUDSON YD  07/07/2016  12:00:00
# 304536  R550  R072  00-03-09  34 ST-HUDSON YD  07/06/2016  12:00:00
# 305484  R550  R072  00-03-0A  34 ST-HUDSON YD  09/11/2016  16:00:00
# 305495  R550  R072  00-03-0A  34 ST-HUDSON YD  09/16/2016  12:00:00
#
#            ENTRIES       EXITS   PREV_DATE  PREV_ENTRIES    PREV_EXITS
# 12145   1557274646  2048593612  07/02/2016  1.557275e+09  2.048594e+09
# ...

# %%
#Interlude:Reverse Entries
pizza_daily[pizza_daily['EXITS']< pizza_daily['PREV_EXITS']]
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 38782   A034  R170  03-06-00   14 ST-UNION SQ  10/06/2016  01:00:00       115
# 43521   A037  R170  05-00-00   14 ST-UNION SQ  08/10/2016  09:00:00      1816
# 68552   N071  R013  00-06-00   34 ST-PENN STA  09/26/2016  12:00:00    524301
# 91052   N502  R021  01-00-00  42 ST-BRYANT PK  08/07/2016  16:00:00      1062
# 91292   N502  R021  01-00-00  42 ST-BRYANT PK  09/18/2016  12:00:00  16827466
# ...      ...   ...       ...              ...         ...       ...       ...
# 287567  R240  R047  00-03-00  GRD CNTRL-42 ST  09/19/2016  13:00:00       206
# 298820  R550  R072  00-03-00  34 ST-HUDSON YD  07/07/2016  12:00:00      1045
# 304536  R550  R072  00-03-09  34 ST-HUDSON YD  07/06/2016  12:00:00      1053
# 305484  R550  R072  00-03-0A  34 ST-HUDSON YD  09/11/2016  16:00:00        62
# 305495  R550  R072  00-03-0A  34 ST-HUDSON YD  09/16/2016  12:00:00         9
#
# ...

# %%
#how many have this?
(pizza_daily[pizza_daily["EXITS"] < pizza_daily["PREV_EXITS"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A    UNIT  SCP       STATION
# A034   R170  03-06-00  14 ST-UNION SQ       1
# A037   R170  05-00-00  14 ST-UNION SQ       1
# N071   R013  00-06-00  34 ST-PENN STA       1
# N502   R021  01-00-00  42 ST-BRYANT PK      3
# R141   R031  00-03-00  34 ST-PENN STA       1
# R148   R033  01-06-00  TIMES SQ-42 ST       2
# R151   R033  00-00-00  TIMES SQ-42 ST       1
#              00-00-04  TIMES SQ-42 ST       1
#              00-00-05  TIMES SQ-42 ST       1
#              00-00-08  TIMES SQ-42 ST       1
# R221   R170  01-00-02  14 ST-UNION SQ       1
#              01-03-00  14 ST-UNION SQ       2
#              01-03-01  14 ST-UNION SQ       2
#              01-03-02  14 ST-UNION SQ       1
#              01-06-01  14 ST-UNION SQ       1
# R227   R131  00-00-00  23 ST              636
# R236   R045  00-00-00  GRD CNTRL-42 ST      1
# R238A  R046  02-00-03  GRD CNTRL-42 ST      1
# R240   R047  00-03-00  GRD CNTRL-42 ST      2
# R550   R072  00-03-00  34 ST-HUDSON YD      1
# ...

# %%
#fix with formula
def get_daily_counts(row, max_counter):
    counter = row['ENTRIES'] - row["PREV_ENTRIES"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['ENTRIES'], row['PREV_ENTRIES'])
        return 0
    return counter
_ = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 67108933 1637369.0
# 115 118685725.0
# 1816 289365136.0
# 1062 10020703.0
# 16827466 75944.0
# 1096 16878205.0
# 1643 9083925.0
# 100663296 35655801.0
# 308 100785629.0
# 67108866 50331984.0
# 66 2147369344.0
# 271 1664120.0

# %%
#THIS IS THE FIX (ENTRIES)
def get_daily_counts(row, max_counter):
    counter = row['ENTRIES'] - row['PREV_ENTRIES']
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['ENTRIES'], row['PREV_ENTRIES'])
        counter = min(row['ENTRIES'], row['PREV_ENTRIES'])
    if counter > max_counter:
        return 0
    return counter

pizza_daily['DAILY_ENTRIES'] = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 67108933 1637369.0
# 115 118685725.0
# 1816 289365136.0
# 1062 10020703.0
# 16827466 75944.0
# 1096 16878205.0
# 1643 9083925.0
# 100663296 35655801.0
# 308 100785629.0
# 67108866 50331984.0
# 66 2147369344.0
# 271 1664120.0

# %%
#THIS IS THE FIX (EXITS)
def get_daily_counts(row, max_counter):
    counter = row['EXITS'] - row['PREV_EXITS']
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['EXITS'], row['PREV_EXITS'])
        counter = min(row['EXITS'], row['PREV_EXITS'])
    if counter > max_counter:
        return 0
    return counter

pizza_daily['DAILY_EXITS'] = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 16777314 4084369.0
# 128 220724554.0
# 272 6276977.0
# 151 7532876.0
# 0 17305251.0

# %%
#how many have this?
pizza_daily[pizza_daily.DAILY_EXITS > 1000000]
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, DATE, TIME, ENTRIES, EXITS, PREV_DATE, PREV_ENTRIES, PREV_EXITS, DAILY_ENTRIES, DAILY_EXITS]
# Index: []

# %%
#combining DAILY Entries and Exits to get total DAILY Total_Foot_Traffic 
pizza_daily["TOTAL_DAILY_FT"] = pizza_daily.DAILY_ENTRIES + pizza_daily.DAILY_EXITS
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  08:00:00  5836454
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  12:00:00  5836602
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  16:00:00  5836826
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  20:00:00  5837134
# ...      ...   ...       ...              ...         ...       ...      ...
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
# 307571  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  08:00:00        1
# 307572  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  12:00:00        1
# 307573  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  16:00:00        1
# 307574  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  20:00:00        1
#
# ...

# %%
#Daily Averages
station_daily = pizza_daily.groupby(["STATION", "DATE"])['DAILY_ENTRIES','DAILY_EXITS', 'TOTAL_DAILY_FT'].mean().reset_index()
station_daily
# Out:
# <ipython-input-103-58f79f96a721>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   station_daily = pizza_daily.groupby(["STATION", "DATE"])['DAILY_ENTRIES','DAILY_EXITS', 'TOTAL_DAILY_FT'].mean().reset_index()
#              STATION        DATE  DAILY_ENTRIES  DAILY_EXITS  TOTAL_DAILY_FT
# 0     14 ST-UNION SQ  07/02/2016     264.736842   265.715789      530.452632
# 1     14 ST-UNION SQ  07/03/2016     231.280702   206.232456      437.513158
# 2     14 ST-UNION SQ  07/04/2016     202.594714   188.929515      391.524229
# 3     14 ST-UNION SQ  07/05/2016     357.588710   331.084677      688.673387
# 4     14 ST-UNION SQ  07/06/2016     447.578947   385.798246      833.377193
# ...              ...         ...            ...          ...             ...
# 1150  TIMES SQ-42 ST  10/10/2016     277.716667   264.233333      541.950000
# ...

# %%
#STATION TOTAL (ALL TIMES)
station_total = pizza_daily.groupby(["STATION"]).sum().sort_values('TOTAL_DAILY_FT', ascending = False).reset_index()
station_total
# Out:
#             STATION        ENTRIES          EXITS  PREV_ENTRIES    PREV_EXITS  \
# 0    34 ST-PENN STA  1610295450547  1025474771636  1.610289e+12  1.025470e+12
# 1   GRD CNTRL-42 ST  2615439735090   482617595501  2.617576e+12  4.826068e+11
# 2   34 ST-HERALD SQ  2059263455467  2156143881773  2.059188e+12  2.156121e+12
# 3    14 ST-UNION SQ   782649051755   237420603917  7.830475e+11  2.376336e+11
# 4             23 ST  4127314822564  3838896352301  4.127305e+12  3.838889e+12
# 5    TIMES SQ-42 ST  3643791836363  2849462114699  3.643819e+12  2.849471e+12
# 6             28 ST   967916390406  1328910290302  9.679119e+11  1.328906e+12
# 7   42 ST-BRYANT PK  1250574636282   912701651263  1.250581e+12  9.127044e+11
# 8             33 ST   296860563761    87035982186  2.968411e+11  8.703393e+10
# 9          ASTOR PL    20536995080    16808149852  2.053554e+10  1.680662e+10
# 10  34 ST-HUDSON YD     2686854052     1682135765  2.686155e+09  1.681133e+09
#
# ...

# %%
#SPLITTING OUT ONLY MIDNIGHT TO 5AM
pizza_daily_5am = pizza_daily[(pizza_daily["TIME"] == "00:00:00") |
                              (pizza_daily['TIME'] == '04:00:00') |
                              (pizza_daily['TIME'] == '01:00:00') |
                              (pizza_daily['TIME'] == '05:00:00')]

pizza_daily_5am
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/02/2016  04:00:00  5836397
# 6       A021  R032  01-00-00   TIMES SQ-42 ST  07/03/2016  00:00:00  5837365
# 7       A021  R032  01-00-00   TIMES SQ-42 ST  07/03/2016  04:00:00  5837418
# 12      A021  R032  01-00-00   TIMES SQ-42 ST  07/04/2016  00:00:00  5838155
# 13      A021  R032  01-00-00   TIMES SQ-42 ST  07/04/2016  04:00:00  5838199
# ...      ...   ...       ...              ...         ...       ...      ...
# 307558  R550  R072  00-05-01  34 ST-HUDSON YD  10/12/2016  04:00:00        1
# 307563  R550  R072  00-05-01  34 ST-HUDSON YD  10/13/2016  00:00:00        1
# 307564  R550  R072  00-05-01  34 ST-HUDSON YD  10/13/2016  04:00:00        1
# 307569  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  00:00:00        1
# 307570  R550  R072  00-05-01  34 ST-HUDSON YD  10/14/2016  04:00:00        1
#
# ...

# %%
station_average_5am = pizza_daily_5am.groupby(['STATION']).mean().sort_values('TOTAL_DAILY_FT', ascending = False).reset_index()

station_average_5am
# Out:
#             STATION       ENTRIES         EXITS  PREV_ENTRIES    PREV_EXITS  \
# 0    14 ST-UNION SQ  3.248797e+07  9.878816e+06  3.250276e+07  9.878814e+06
# 1    TIMES SQ-42 ST  1.148299e+08  9.024717e+07  1.148297e+08  9.024708e+07
# 2   34 ST-HERALD SQ  5.981698e+07  6.266234e+07  5.981682e+07  6.266225e+07
# 3   42 ST-BRYANT PK  9.317214e+07  6.801515e+07  9.317197e+07  6.801509e+07
# 4   GRD CNTRL-42 ST  6.670711e+07  1.221170e+07  6.670700e+07  1.221163e+07
# 5          ASTOR PL  2.666724e+06  2.203139e+06  2.666623e+06  2.203089e+06
# 6             23 ST  9.174315e+07  8.532169e+07  9.174305e+07  8.532165e+07
# 7    34 ST-PENN STA  7.027023e+06  4.584419e+06  7.026937e+06  4.584359e+06
# 8             28 ST  4.154563e+07  5.699373e+07  4.154555e+07  5.699368e+07
# 9             33 ST  2.136928e+07  6.280084e+06  2.136922e+07  6.280054e+06
# 10  34 ST-HUDSON YD  2.376688e+05  1.487445e+05  2.376367e+05  1.487223e+05
#
#     DAILY_ENTRIES  DAILY_EXITS  TOTAL_DAILY_FT
# ...

# %%
# importing MatPlot

import matplotlib.pyplot as plt

# %%
#plotting a bar graph showing the foot_traffic of all stations in comparison to each other
plt.bar(station_average_5am.STATION, station_average_5am.TOTAL_DAILY_FT)
plt.xticks(rotation = 90)
plt.title("Late Night Total Foot Traffic", fontsize = 12, color="b")
# Out:
# Text(0.5, 1.0, 'Late Night Total Foot Traffic')
