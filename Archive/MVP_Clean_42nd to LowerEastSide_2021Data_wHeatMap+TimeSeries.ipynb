# %%
import pandas as pd

# %%
a = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_211030.txt")
b = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_211023.txt")
c = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_211016.txt")

d = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_211009.txt")
e = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_211002.txt")
f = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210925.txt")
g = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210918.txt")

h = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210911.txt")
i = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210904.txt")
j = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210828.txt")
k = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210821.txt")

l = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210814.txt")
m = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210807.txt")
n = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210731.txt")
o = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_210724.txt")

# %%
#Concat datasets for 15 weeks
df = pd.concat([o,n,m,l,k,j,i,h,g,f,e,d,c,b,a])

df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209879  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209880  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209881  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209882  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209883  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
#
#             TIME     DESC  ENTRIES  \
# 0       00:00:00  REGULAR  7603734
# 1       04:00:00  REGULAR  7603744
# 2       08:00:00  REGULAR  7603756
# 3       12:00:00  REGULAR  7603804
# 4       16:00:00  REGULAR  7603900
# ...          ...      ...      ...
# 209879  05:00:00  REGULAR     5554
# 209880  09:00:00  REGULAR     5554
# 209881  13:00:00  REGULAR     5554
# 209882  17:00:00  REGULAR     5554
# 209883  21:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2600230
# 1                                                 2600236
# 2                                                 2600252
# 3                                                 2600302
# 4                                                 2600327
# ...                                                   ...
# 209879                                                680
# 209880                                                680
# 209881                                                680
# 209882                                                681
# 209883                                                681
#
# [3145450 rows x 11 columns]

# %%
#Data Cleaning - viewing all columns
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
#Declaring new variable and stripping all column names of spaces
df.columns = [column.strip() for column in df.columns]
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
#combining Entries and Exits to get total Foot_Traffic <=== this step is no longer needed here now, will do again later
df["Foot_Traffic"] = df.ENTRIES + df.EXITS
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209879  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209880  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209881  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209882  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209883  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
#
#             TIME     DESC  ENTRIES    EXITS  Foot_Traffic
# 0       00:00:00  REGULAR  7603734  2600230      10203964
# 1       04:00:00  REGULAR  7603744  2600236      10203980
# 2       08:00:00  REGULAR  7603756  2600252      10204008
# 3       12:00:00  REGULAR  7603804  2600302      10204106
# 4       16:00:00  REGULAR  7603900  2600327      10204227
# ...          ...      ...      ...      ...           ...
# 209879  05:00:00  REGULAR     5554      680          6234
# 209880  09:00:00  REGULAR     5554      680          6234
# 209881  13:00:00  REGULAR     5554      680          6234
# 209882  17:00:00  REGULAR     5554      681          6235
# 209883  21:00:00  REGULAR     5554      681          6235
#
# [3145450 rows x 12 columns]

# %%
df.DATE.value_counts().sort_index().reset_index()
# Out:
#           index   DATE
# 0    07/17/2021  30193
# 1    07/18/2021  29840
# 2    07/19/2021  29909
# 3    07/20/2021  29811
# 4    07/21/2021  29772
# ..          ...    ...
# 100  10/25/2021  29964
# 101  10/26/2021  30322
# 102  10/27/2021  29936
# 103  10/28/2021  29858
# 104  10/29/2021  30024
#
# [105 rows x 2 columns]

# %%
#Add Date_Time Column
import datetime

# %%
df['Date_Time'] = pd.to_datetime(df.DATE+" "+df.TIME)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3145450 entries, 0 to 209883
# Data columns (total 13 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   C/A           object
#  1   UNIT          object
#  2   SCP           object
#  3   STATION       object
#  4   LINENAME      object
#  5   DIVISION      object
#  6   DATE          object
#  7   TIME          object
#  8   DESC          object
#  9   ENTRIES       int64
#  10  EXITS         int64
#  11  Foot_Traffic  int64
#  12  Date_Time     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(9)
# memory usage: 336.0+ MB

# %%
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  07/17/2021
# ...       ...   ...       ...            ...      ...      ...         ...
# 209879  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209880  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209881  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209882  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
# 209883  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  10/29/2021
#
#             TIME     DESC  ENTRIES    EXITS  Foot_Traffic           Date_Time
# 0       00:00:00  REGULAR  7603734  2600230      10203964 2021-07-17 00:00:00
# 1       04:00:00  REGULAR  7603744  2600236      10203980 2021-07-17 04:00:00
# 2       08:00:00  REGULAR  7603756  2600252      10204008 2021-07-17 08:00:00
# 3       12:00:00  REGULAR  7603804  2600302      10204106 2021-07-17 12:00:00
# 4       16:00:00  REGULAR  7603900  2600327      10204227 2021-07-17 16:00:00
# ...          ...      ...      ...      ...           ...                 ...
# 209879  05:00:00  REGULAR     5554      680          6234 2021-10-29 05:00:00
# 209880  09:00:00  REGULAR     5554      680          6234 2021-10-29 09:00:00
# 209881  13:00:00  REGULAR     5554      680          6234 2021-10-29 13:00:00
# 209882  17:00:00  REGULAR     5554      681          6235 2021-10-29 17:00:00
# 209883  21:00:00  REGULAR     5554      681          6235 2021-10-29 21:00:00
#
# [3145450 rows x 13 columns]

# %%
mask = ((df["C/A"]=='A002') &
        (df["UNIT"]=='R051') &
        (df["SCP"]=='02-00-00') &
        (df["STATION"]=='59 ST')
       )

df[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  07/17/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  07/17/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  07/17/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  07/17/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  07/17/2021  16:00:00
#
#       DESC  ENTRIES    EXITS  Foot_Traffic           Date_Time
# 0  REGULAR  7603734  2600230      10203964 2021-07-17 00:00:00
# 1  REGULAR  7603744  2600236      10203980 2021-07-17 04:00:00
# 2  REGULAR  7603756  2600252      10204008 2021-07-17 08:00:00
# 3  REGULAR  7603804  2600302      10204106 2021-07-17 12:00:00
# 4  REGULAR  7603900  2600327      10204227 2021-07-17 16:00:00

# %%
#Filtering out Stations for Pizza

df_pizza = df[       (df["STATION"] == 'TIMES SQ-42 ST') | # Midtown Tourist
                     (df["STATION"] == '34 ST-HERALD SQ')| # KoreaTown
                     (df["STATION"] == '42 ST-BRYANT PK')| # Midtown / Tourist
                     (df["STATION"] == 'GRD CNTRL-42 ST')| # Midtown / Tourist
                     (df["STATION"] == '34 ST-PENN STA') | # Midtown / Tourist
                     (df["STATION"] == '14 ST-UNION SQ') | # NYU / Tourist
                     (df["STATION"] == '34 ST-HUDSON YD')| # Hudson Yard
                     (df["STATION"] == '23 ST') |          # FlatIron
                     (df["STATION"] == '28 ST') |          # Gramarcy
                     (df["STATION"] == '33 ST') |          # Murray Hill
                     (df["STATION"] == 'CHRISTOPHER ST') | # West Village
                     (df["STATION"] == '14 ST') |          # West Village
                     (df["STATION"] == 'W 4 ST-WASH SQ') | # West Village
                     (df["STATION"] == 'ASTOR PL') |       # East Village
                     (df["STATION"] == '3 AV') |           # East Village
                     (df["STATION"] == '1 AV') |           # East Village
                     (df["STATION"] == 'DELANCEY/ESSEX') | # Lower East Side
                     (df["STATION"] == 'EAST BROADWAY')    # Lower East Side
             ]
df_pizza
# Out:
#          C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2990    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2991    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2992    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2993    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2994    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...      ...   ...       ...              ...           ...      ...
# 197585  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197586  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197587  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197588  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197589  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
#
#               DATE      TIME     DESC   ENTRIES     EXITS  Foot_Traffic  \
# 2990    07/17/2021  00:00:00  REGULAR  10037293  12611537      22648830
# 2991    07/17/2021  04:00:00  REGULAR  10037323  12611581      22648904
# 2992    07/17/2021  08:00:00  REGULAR  10037356  12611642      22648998
# 2993    07/17/2021  12:00:00  REGULAR  10037462  12611973      22649435
# 2994    07/17/2021  16:00:00  REGULAR  10037615  12612370      22649985
# ...            ...       ...      ...       ...       ...           ...
# 197585  10/29/2021  00:00:00  REGULAR         1       222           223
# 197586  10/29/2021  04:00:00  REGULAR         1       222           223
# 197587  10/29/2021  12:00:00  REGULAR         1       223           224
# 197588  10/29/2021  16:00:00  REGULAR         1       223           224
# 197589  10/29/2021  20:00:00  REGULAR         1       223           224
#
#                  Date_Time
# 2990   2021-07-17 00:00:00
# 2991   2021-07-17 04:00:00
# 2992   2021-07-17 08:00:00
# 2993   2021-07-17 12:00:00
# 2994   2021-07-17 16:00:00
# ...                    ...
# 197585 2021-10-29 00:00:00
# 197586 2021-10-29 04:00:00
# 197587 2021-10-29 12:00:00
# 197588 2021-10-29 16:00:00
# 197589 2021-10-29 20:00:00
#
# [422677 rows x 13 columns]

# %%
#Check for Dups
(df_pizza.groupby(["C/A", "UNIT", "SCP", "STATION", "Date_Time"]).ENTRIES.count().reset_index().sort_values("ENTRIES", ascending = False))
# Out:
#          C/A  UNIT       SCP          STATION           Date_Time  ENTRIES
# 0       A021  R032  01-00-00   TIMES SQ-42 ST 2021-07-17 00:00:00        1
# 281782  R148  R033  01-00-04   TIMES SQ-42 ST 2021-10-03 16:00:00        1
# 281792  R148  R033  01-00-04   TIMES SQ-42 ST 2021-10-05 08:00:00        1
# 281791  R148  R033  01-00-04   TIMES SQ-42 ST 2021-10-05 04:00:00        1
# 281790  R148  R033  01-00-04   TIMES SQ-42 ST 2021-10-05 00:00:00        1
# ...      ...   ...       ...              ...                 ...      ...
# 140889  N503  R021  00-00-03  42 ST-BRYANT PK 2021-07-27 20:00:00        1
# 140888  N503  R021  00-00-03  42 ST-BRYANT PK 2021-07-27 16:00:00        1
# 140887  N503  R021  00-00-03  42 ST-BRYANT PK 2021-07-27 12:00:00        1
# 140886  N503  R021  00-00-03  42 ST-BRYANT PK 2021-07-27 08:00:00        1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD 2021-10-29 20:00:00        1
#
# [422677 rows x 6 columns]

# %%
#Drop Duplicates just to see if same row exists

# %%
df2 = df_pizza.drop_duplicates(subset=['C/A', 'UNIT', "SCP", "STATION", "Date_Time"])
df2.shape
# Out:
# (422677, 13)

# %%
#No Duplicates in df_pizza
#Need to Drop Columns - Actual FT

df_pizza
# Out:
#          C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 2990    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2991    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2992    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2993    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# 2994    A021  R032  01-00-00   TIMES SQ-42 ST  ACENQRS1237W      BMT
# ...      ...   ...       ...              ...           ...      ...
# 197585  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197586  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197587  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197588  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
# 197589  R551  R072  01-05-01  34 ST-HUDSON YD             7      IRT
#
#               DATE      TIME     DESC   ENTRIES     EXITS  Foot_Traffic  \
# 2990    07/17/2021  00:00:00  REGULAR  10037293  12611537      22648830
# 2991    07/17/2021  04:00:00  REGULAR  10037323  12611581      22648904
# 2992    07/17/2021  08:00:00  REGULAR  10037356  12611642      22648998
# 2993    07/17/2021  12:00:00  REGULAR  10037462  12611973      22649435
# 2994    07/17/2021  16:00:00  REGULAR  10037615  12612370      22649985
# ...            ...       ...      ...       ...       ...           ...
# 197585  10/29/2021  00:00:00  REGULAR         1       222           223
# 197586  10/29/2021  04:00:00  REGULAR         1       222           223
# 197587  10/29/2021  12:00:00  REGULAR         1       223           224
# 197588  10/29/2021  16:00:00  REGULAR         1       223           224
# 197589  10/29/2021  20:00:00  REGULAR         1       223           224
#
#                  Date_Time
# 2990   2021-07-17 00:00:00
# 2991   2021-07-17 04:00:00
# 2992   2021-07-17 08:00:00
# 2993   2021-07-17 12:00:00
# 2994   2021-07-17 16:00:00
# ...                    ...
# 197585 2021-10-29 00:00:00
# 197586 2021-10-29 04:00:00
# 197587 2021-10-29 12:00:00
# 197588 2021-10-29 16:00:00
# 197589 2021-10-29 20:00:00
#
# [422677 rows x 13 columns]

# %%
#CREATION OF PIZZA_DAILY
#maximum ENTRIES per day. Pizza_daily (newly created) is only ENTRIES, will create Exits later

pizza_daily = (df_pizza
                  .groupby(["C/A", "UNIT", "SCP", "STATION","DATE", "TIME"], as_index=False)
                  ['ENTRIES', 'EXITS'].last())

pizza_daily
# Out:
# <ipython-input-274-663c15bbae88>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pizza_daily = (df_pizza
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 0       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  00:00:00  10037293
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS
# 0       12611537
# 1       12611581
# 2       12611642
# 3       12611973
# 4       12612370
# ...          ...
# 422672       222
# 422673       222
# 422674       223
# 422675       223
# 422676       223
#
# [422677 rows x 8 columns]

# %%
#Create two columns with shift(1)

pizza_daily[['PREV_DATE', 'PREV_ENTRIES', 'PREV_EXITS']] = (pizza_daily
                                                 .groupby(['C/A', 'UNIT', 'SCP', 'STATION'])['DATE', 'ENTRIES', 'EXITS']
                                                 .apply(lambda grp: grp.shift(1))
                                             )
pizza_daily.head()
# Out:
# <ipython-input-276-d241225b51be>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pizza_daily[['PREV_DATE', 'PREV_ENTRIES', 'PREV_EXITS']] = (pizza_daily
#     C/A  UNIT       SCP         STATION        DATE      TIME   ENTRIES  \
# 0  A021  R032  01-00-00  TIMES SQ-42 ST  07/17/2021  00:00:00  10037293
# 1  A021  R032  01-00-00  TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2  A021  R032  01-00-00  TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3  A021  R032  01-00-00  TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4  A021  R032  01-00-00  TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
#
#       EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 0  12611537         NaN           NaN         NaN
# 1  12611581  07/17/2021    10037293.0  12611537.0
# 2  12611642  07/17/2021    10037323.0  12611581.0
# 3  12611973  07/17/2021    10037356.0  12611642.0
# 4  12612370  07/17/2021    10037462.0  12611973.0

# %%
pizza_daily.tail()
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME  ENTRIES  \
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00        1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00        1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00        1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00        1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00        1
#
#         EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 422672    222  10/28/2021           1.0       221.0
# 422673    222  10/29/2021           1.0       222.0
# 422674    223  10/29/2021           1.0       222.0
# 422675    223  10/29/2021           1.0       223.0
# 422676    223  10/29/2021           1.0       223.0

# %%
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  20:00:00  10037797
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 1       12611581  07/17/2021    10037293.0  12611537.0
# 2       12611642  07/17/2021    10037323.0  12611581.0
# 3       12611973  07/17/2021    10037356.0  12611642.0
# 4       12612370  07/17/2021    10037462.0  12611973.0
# 5       12612768  07/17/2021    10037615.0  12612370.0
# ...          ...         ...           ...         ...
# 422672       222  10/28/2021           1.0       221.0
# 422673       222  10/29/2021           1.0       222.0
# 422674       223  10/29/2021           1.0       222.0
# 422675       223  10/29/2021           1.0       223.0
# 422676       223  10/29/2021           1.0       223.0
#
# [422000 rows x 11 columns]

# %%
#drop na for PREV_DATE column
pizza_daily.dropna(subset=["PREV_DATE"], axis = 0, inplace=True)
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  20:00:00  10037797
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 1       12611581  07/17/2021    10037293.0  12611537.0
# 2       12611642  07/17/2021    10037323.0  12611581.0
# 3       12611973  07/17/2021    10037356.0  12611642.0
# 4       12612370  07/17/2021    10037462.0  12611973.0
# 5       12612768  07/17/2021    10037615.0  12612370.0
# ...          ...         ...           ...         ...
# 422672       222  10/28/2021           1.0       221.0
# 422673       222  10/29/2021           1.0       222.0
# 422674       223  10/29/2021           1.0       222.0
# 422675       223  10/29/2021           1.0       223.0
# 422676       223  10/29/2021           1.0       223.0
#
# [422000 rows x 11 columns]

# %%
#Interlude:Reverse Entries
pizza_daily[pizza_daily['ENTRIES']< pizza_daily['PREV_ENTRIES']]
# Out:
#           C/A  UNIT       SCP          STATION        DATE      TIME  \
# 65101   H007A  R248  02-03-04             1 AV  10/22/2021  00:00:00
# 80762    N068  R012  03-00-02   34 ST-PENN STA  09/21/2021  00:00:00
# 88007    N070  R012  04-05-01   34 ST-PENN STA  07/30/2021  16:00:00
# 102325   N073  R013  02-00-04   34 ST-PENN STA  10/13/2021  16:00:00
# 116305   N078  R175  01-00-03            14 ST  07/17/2021  05:00:00
# ...       ...   ...       ...              ...         ...       ...
# 366258   R237  R046  01-00-06  GRD CNTRL-42 ST  10/29/2021  08:00:00
# 366259   R237  R046  01-00-06  GRD CNTRL-42 ST  10/29/2021  12:00:00
# 366260   R237  R046  01-00-06  GRD CNTRL-42 ST  10/29/2021  16:00:00
# 366261   R237  R046  01-00-06  GRD CNTRL-42 ST  10/29/2021  20:00:00
# 374329   R238  R046  00-03-00  GRD CNTRL-42 ST  09/21/2021  16:00:00
#
#            ENTRIES       EXITS   PREV_DATE  PREV_ENTRIES    PREV_EXITS
# 65101           44           4  10/21/2021  1.148450e+05  2.477200e+04
# 80762            8           2  09/20/2021  3.902700e+04  1.188500e+04
# 88007            0           9  07/30/2021  1.174405e+08  5.490000e+02
# 102325          12           9  10/13/2021  1.779830e+05  1.797610e+05
# 116305  2128665973  1154781821  07/17/2021  2.128666e+09  1.154782e+09
# ...            ...         ...         ...           ...           ...
# 366258  1254603232   723290208  10/29/2021  1.254603e+09  7.232902e+08
# 366259  1254603191   723290253  10/29/2021  1.254603e+09  7.232902e+08
# 366260  1254603100   723290282  10/29/2021  1.254603e+09  7.232903e+08
# 366261  1254602951   723290314  10/29/2021  1.254603e+09  7.232903e+08
# 374329          40          49  09/21/2021  1.187700e+05  1.347400e+05
#
# [4274 rows x 11 columns]

# %%
#Interlude:Reverse Entries
pizza_daily[pizza_daily['EXITS']< pizza_daily['PREV_EXITS']]
# Out:
#           C/A  UNIT       SCP          STATION        DATE      TIME  \
# 65101   H007A  R248  02-03-04             1 AV  10/22/2021  00:00:00
# 80762    N068  R012  03-00-02   34 ST-PENN STA  09/21/2021  00:00:00
# 88007    N070  R012  04-05-01   34 ST-PENN STA  07/30/2021  16:00:00
# 102325   N073  R013  02-00-04   34 ST-PENN STA  10/13/2021  16:00:00
# 116305   N078  R175  01-00-03            14 ST  07/17/2021  05:00:00
# ...       ...   ...       ...              ...         ...       ...
# 358809   R236  R045  00-03-01  GRD CNTRL-42 ST  10/29/2021  09:00:00
# 358810   R236  R045  00-03-01  GRD CNTRL-42 ST  10/29/2021  13:00:00
# 358811   R236  R045  00-03-01  GRD CNTRL-42 ST  10/29/2021  17:00:00
# 358812   R236  R045  00-03-01  GRD CNTRL-42 ST  10/29/2021  21:00:00
# 374329   R238  R046  00-03-00  GRD CNTRL-42 ST  09/21/2021  16:00:00
#
#            ENTRIES       EXITS   PREV_DATE  PREV_ENTRIES    PREV_EXITS
# 65101           44           4  10/21/2021  1.148450e+05  2.477200e+04
# 80762            8           2  09/20/2021  3.902700e+04  1.188500e+04
# 88007            0           9  07/30/2021  1.174405e+08  5.490000e+02
# 102325          12           9  10/13/2021  1.779830e+05  1.797610e+05
# 116305  2128665973  1154781821  07/17/2021  2.128666e+09  1.154782e+09
# ...            ...         ...         ...           ...           ...
# 358809   591936479   886071437  10/29/2021  5.919365e+08  8.860714e+08
# 358810   591936454   886071434  10/29/2021  5.919365e+08  8.860714e+08
# 358811   591936388   886071431  10/29/2021  5.919365e+08  8.860714e+08
# 358812   591936329   886071430  10/29/2021  5.919364e+08  8.860714e+08
# 374329          40          49  09/21/2021  1.187700e+05  1.347400e+05
#
# [2259 rows x 11 columns]

# %%
#how many have this?
(pizza_daily[pizza_daily["EXITS"] < pizza_daily["PREV_EXITS"]]
    .groupby(["C/A", "UNIT", "SCP", "STATION"])
    .size())
# Out:
# C/A    UNIT  SCP       STATION
# A034   R170  03-06-00  14 ST-UNION SQ       1
# A037   R170  05-00-00  14 ST-UNION SQ       1
# N071   R013  00-06-00  34 ST-PENN STA       1
# N078   R175  01-00-01  14 ST                1
# N080   R138  00-00-00  W 4 ST-WASH SQ       1
# N083   R138  01-00-01  W 4 ST-WASH SQ       1
# N502   R021  01-00-00  42 ST-BRYANT PK      3
# N526   R142  02-00-00  DELANCEY/ESSEX       1
#              02-00-01  DELANCEY/ESSEX       1
#              02-00-02  DELANCEY/ESSEX       1
# N529   R257  00-00-01  EAST BROADWAY        1
# R127   R105  00-00-00  14 ST              630
# R141   R031  00-03-00  34 ST-PENN STA       1
# R148   R033  01-06-00  TIMES SQ-42 ST       2
# R151   R033  00-00-00  TIMES SQ-42 ST       1
#              00-00-04  TIMES SQ-42 ST       1
#              00-00-05  TIMES SQ-42 ST       1
#              00-00-08  TIMES SQ-42 ST       1
# R221   R170  01-00-02  14 ST-UNION SQ       1
#              01-03-00  14 ST-UNION SQ       2
#              01-03-01  14 ST-UNION SQ       2
#              01-03-02  14 ST-UNION SQ       1
#              01-06-01  14 ST-UNION SQ       1
# R227   R131  00-00-00  23 ST              636
# R236   R045  00-00-00  GRD CNTRL-42 ST      1
# R238A  R046  02-00-03  GRD CNTRL-42 ST      1
# R240   R047  00-03-00  GRD CNTRL-42 ST      2
# R550   R072  00-03-00  34 ST-HUDSON YD      1
#              00-03-09  34 ST-HUDSON YD      1
#              00-03-0A  34 ST-HUDSON YD      2
# dtype: int64

# %%
#fix with formula
def get_daily_counts(row, max_counter):
    counter = row['ENTRIES'] - row["PREV_ENTRIES"]
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['ENTRIES'], row['PREV_ENTRIES'])
        return 0
    return counter
_ = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 0 117440512.0
# 2150004 1043925813.0
# 34 6214051.0
# 173 15689534.0
# 11123659 4624026.0
# 5 11123659.0
# 1891101745 1104755.0
# 43 3154069.0
# 114 1953573.0
# 90 4788322.0

# %%
#THIS IS THE FIX (ENTRIES)
def get_daily_counts(row, max_counter):
    counter = row['ENTRIES'] - row['PREV_ENTRIES']
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['ENTRIES'], row['PREV_ENTRIES'])
        counter = min(row['ENTRIES'], row['PREV_ENTRIES'])
    if counter > max_counter:
        return 0
    return counter

pizza_daily['4HR_ENTRIES'] = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 0 117440512.0
# 2150004 1043925813.0
# 34 6214051.0
# 173 15689534.0
# 11123659 4624026.0
# 5 11123659.0
# 1891101745 1104755.0
# 43 3154069.0
# 114 1953573.0
# 90 4788322.0

# %%
#THIS IS THE FIX (EXITS)
def get_daily_counts(row, max_counter):
    counter = row['EXITS'] - row['PREV_EXITS']
    if counter < 0:
        counter = -counter
    if counter > max_counter:
        print(row['EXITS'], row['PREV_EXITS'])
        counter = min(row['EXITS'], row['PREV_EXITS'])
    if counter > max_counter:
        return 0
    return counter

pizza_daily['4HR_EXITS'] = pizza_daily.apply(get_daily_counts, axis=1, max_counter=1000000)
# Out:
# 306 1152627.0
# 1037726 1009318796.0
# 208 8944327.0
# 14324221 1392264.0
# 5 14324225.0
# 1428704905 145278.0
# 316 1895949.0
# 63 2607848.0

# %%
#how many have this?
pizza_daily[pizza_daily['4HR_EXITS'] > 1000000]
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, DATE, TIME, ENTRIES, EXITS, PREV_DATE, PREV_ENTRIES, PREV_EXITS, 4HR_ENTRIES, 4HR_EXITS]
# Index: []

# %%
#combining DAILY Entries and Exits to get total DAILY Total_Foot_Traffic 
pizza_daily["TOTAL_4HR_FT"] = pizza_daily['4HR_ENTRIES'] + pizza_daily['4HR_EXITS']
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  20:00:00  10037797
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS  4HR_ENTRIES  \
# 1       12611581  07/17/2021    10037293.0  12611537.0         30.0
# 2       12611642  07/17/2021    10037323.0  12611581.0         33.0
# 3       12611973  07/17/2021    10037356.0  12611642.0        106.0
# 4       12612370  07/17/2021    10037462.0  12611973.0        153.0
# 5       12612768  07/17/2021    10037615.0  12612370.0        182.0
# ...          ...         ...           ...         ...          ...
# 422672       222  10/28/2021           1.0       221.0          0.0
# 422673       222  10/29/2021           1.0       222.0          0.0
# 422674       223  10/29/2021           1.0       222.0          0.0
# 422675       223  10/29/2021           1.0       223.0          0.0
# 422676       223  10/29/2021           1.0       223.0          0.0
#
#         4HR_EXITS  TOTAL_4HR_FT
# 1            44.0          74.0
# 2            61.0          94.0
# 3           331.0         437.0
# 4           397.0         550.0
# 5           398.0         580.0
# ...           ...           ...
# 422672        1.0           1.0
# 422673        0.0           0.0
# 422674        1.0           1.0
# 422675        0.0           0.0
# 422676        0.0           0.0
#
# [422000 rows x 14 columns]

# %%
#Daily Averages
station_daily = pizza_daily.groupby(["STATION", "DATE"])['4HR_ENTRIES','4HR_EXITS', 'TOTAL_4HR_FT'].mean().reset_index()
station_daily
# Out:
# <ipython-input-290-e4edc52aba14>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   station_daily = pizza_daily.groupby(["STATION", "DATE"])['4HR_ENTRIES','4HR_EXITS', 'TOTAL_4HR_FT'].mean().reset_index()
#              STATION        DATE  4HR_ENTRIES   4HR_EXITS  TOTAL_4HR_FT
# 0               1 AV  07/17/2021    44.925000   95.366667    140.291667
# 1               1 AV  07/18/2021    41.861111   83.513889    125.375000
# 2               1 AV  07/19/2021    51.201389   91.263889    142.465278
# 3               1 AV  07/20/2021    53.250000   92.236111    145.486111
# 4               1 AV  07/21/2021    56.493056   97.791667    154.284722
# ...              ...         ...          ...         ...           ...
# 1884  W 4 ST-WASH SQ  10/25/2021   126.517544  194.482456    321.000000
# 1885  W 4 ST-WASH SQ  10/26/2021   116.412281  186.105263    302.517544
# 1886  W 4 ST-WASH SQ  10/27/2021   140.982456  234.771930    375.754386
# 1887  W 4 ST-WASH SQ  10/28/2021   149.605263  246.228070    395.833333
# 1888  W 4 ST-WASH SQ  10/29/2021   150.122807  245.991228    396.114035
#
# [1889 rows x 5 columns]

# %%
#STATION TOTAL (ALL TIMES)
station_total = pizza_daily.groupby(["STATION"]).sum().sort_values('TOTAL_4HR_FT', ascending = False).reset_index()
station_total
# Out:
#             STATION        ENTRIES          EXITS  PREV_ENTRIES    PREV_EXITS  \
# 0    34 ST-PENN STA  2919350443596  3252554563603  2.919464e+12  3.252549e+12
# 1   GRD CNTRL-42 ST  1353245663065  1178566102420  1.353242e+12  1.178561e+12
# 2    14 ST-UNION SQ   172313816127   124108309585  1.723128e+11  1.241063e+11
# 3   34 ST-HERALD SQ  1940399469959  2399825369801  1.941438e+12  2.400829e+12
# 4    TIMES SQ-42 ST  2940988230682  2362814906011  2.939103e+12  2.361384e+12
# 5             23 ST  3610344963754  3640269803422  3.610342e+12  3.640266e+12
# 6             14 ST  2326784786399  1774886672194  2.326789e+12  1.774885e+12
# 7    W 4 ST-WASH SQ    53170584243    52788179928  5.316955e+10  5.278704e+10
# 8             28 ST   806092862534  1024535668796  8.060915e+11  1.024534e+12
# 9             33 ST   231069948906    44903328851  2.310739e+11  4.490500e+10
# 10  42 ST-BRYANT PK  1367263461497   944920972009  1.367262e+12  9.449193e+11
# 11             1 AV   297369791044   300522802761  2.973690e+11  3.005212e+11
# 12   DELANCEY/ESSEX    46982727205    41027902707  4.698168e+10  4.102655e+10
# 13  34 ST-HUDSON YD    14506899265    14073772403  1.450623e+10  1.407276e+10
# 14   CHRISTOPHER ST    26649659726    15300155357  2.664911e+10  1.529946e+10
# 15         ASTOR PL    12391313115    16366700201  1.239083e+10  1.636583e+10
# 16    EAST BROADWAY    90719911218    24829957165  9.073505e+10  2.483838e+10
# 17             3 AV    17305850526    18435149665  1.730561e+10  1.843474e+10
#
#     4HR_ENTRIES  4HR_EXITS  TOTAL_4HR_FT
# 0     5431162.0  7639904.0    13071066.0
# 1     3684192.0  5383042.0     9067234.0
# 2     3441600.0  5575585.0     9017185.0
# 3     3744934.0  5138060.0     8882994.0
# 4     2835845.0  4762289.0     7598134.0
# 5     3336068.0  3969265.0     7305333.0
# 6     1984039.0  3587105.0     5571144.0
# 7     1769843.0  2295702.0     4065545.0
# 8     1351380.0  2022013.0     3373393.0
# 9     2061636.0  1175870.0     3237506.0
# 10    1084217.0  1645083.0     2729300.0
# 11     974171.0  1608655.0     2582826.0
# 12    1050432.0  1350295.0     2400727.0
# 13     672998.0  1009520.0     1682518.0
# 14     687776.0   885534.0     1573310.0
# 15     486342.0   868413.0     1354755.0
# 16     546628.0   523373.0     1070001.0
# 17     244550.0   406999.0      651549.0

# %%
#SPLITTING OUT ONLY MIDNIGHT TO 5AM
pizza_daily_5am = pizza_daily[(pizza_daily["TIME"] == "00:00:00") |
                              (pizza_daily['TIME'] == '04:00:00') |
                              (pizza_daily['TIME'] == '01:00:00') |
                              (pizza_daily['TIME'] == '05:00:00')]

pizza_daily_5am
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 6       A021  R032  01-00-00   TIMES SQ-42 ST  07/18/2021  00:00:00  10037911
# 7       A021  R032  01-00-00   TIMES SQ-42 ST  07/18/2021  04:00:00  10037934
# 12      A021  R032  01-00-00   TIMES SQ-42 ST  07/19/2021  00:00:00  10038304
# 13      A021  R032  01-00-00   TIMES SQ-42 ST  07/19/2021  04:00:00  10038329
# ...      ...   ...       ...              ...         ...       ...       ...
# 422661  R551  R072  01-05-01  34 ST-HUDSON YD  10/27/2021  04:00:00         1
# 422666  R551  R072  01-05-01  34 ST-HUDSON YD  10/28/2021  00:00:00         1
# 422667  R551  R072  01-05-01  34 ST-HUDSON YD  10/28/2021  04:00:00         1
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS  4HR_ENTRIES  \
# 1       12611581  07/17/2021    10037293.0  12611537.0         30.0
# 6       12612929  07/17/2021    10037797.0  12612768.0        114.0
# 7       12612952  07/18/2021    10037911.0  12612929.0         23.0
# 12      12613679  07/18/2021    10038201.0  12613529.0        103.0
# 13      12613704  07/19/2021    10038304.0  12613679.0         25.0
# ...          ...         ...           ...         ...          ...
# 422661       220  10/27/2021           1.0       220.0          0.0
# 422666       221  10/27/2021           1.0       221.0          0.0
# 422667       221  10/28/2021           1.0       221.0          0.0
# 422672       222  10/28/2021           1.0       221.0          0.0
# 422673       222  10/29/2021           1.0       222.0          0.0
#
#         4HR_EXITS  TOTAL_4HR_FT
# 1            44.0          74.0
# 6           161.0         275.0
# 7            23.0          46.0
# 12          150.0         253.0
# 13           25.0          50.0
# ...           ...           ...
# 422661        0.0           0.0
# 422666        0.0           0.0
# 422667        0.0           0.0
# 422672        1.0           1.0
# 422673        0.0           0.0
#
# [133744 rows x 14 columns]

# %%
station_average_5am = pizza_daily_5am.groupby(['STATION']).mean().sort_values('TOTAL_4HR_FT', ascending = False).reset_index()

station_average_5am
# Out:
#             STATION       ENTRIES         EXITS  PREV_ENTRIES    PREV_EXITS  \
# 0    CHRISTOPHER ST  6.918423e+06  3.920482e+06  6.918332e+06  3.920400e+06
# 1    W 4 ST-WASH SQ  4.457847e+06  4.423881e+06  4.457760e+06  4.423814e+06
# 2    TIMES SQ-42 ST  1.046340e+08  8.399643e+07  1.046339e+08  8.399637e+07
# 3              1 AV  1.935302e+07  1.955901e+07  1.935301e+07  1.955896e+07
# 4              3 AV  4.581650e+06  4.877514e+06  4.581600e+06  4.877454e+06
# 5   34 ST-HERALD SQ  5.704223e+07  7.055146e+07  5.713493e+07  7.064119e+07
# 6    14 ST-UNION SQ  6.665773e+06  4.803903e+06  6.665719e+06  4.803862e+06
# 7    DELANCEY/ESSEX  3.937789e+06  3.438504e+06  3.937746e+06  3.438460e+06
# 8   42 ST-BRYANT PK  1.035379e+08  7.155369e+07  1.035378e+08  7.155366e+07
# 9          ASTOR PL  1.641917e+06  2.164673e+06  1.641880e+06  2.164639e+06
# 10   34 ST-PENN STA  2.005527e+07  2.181763e+07  2.005525e+07  2.181759e+07
# 11    EAST BROADWAY  1.325051e+07  3.623770e+06  1.325048e+07  3.623734e+06
# 12            14 ST  7.257404e+07  5.533091e+07  7.257401e+07  5.533088e+07
# 13            23 ST  7.870375e+07  7.934580e+07  7.870372e+07  7.934578e+07
# 14            28 ST  3.279532e+07  4.169194e+07  3.279530e+07  4.169191e+07
# 15  GRD CNTRL-42 ST  2.334105e+07  2.030227e+07  2.334103e+07  2.030224e+07
# 16            33 ST  1.673761e+07  3.250957e+06  1.673760e+07  3.250937e+06
# 17  34 ST-HUDSON YD  7.699112e+05  7.476266e+05  7.698910e+05  7.476127e+05
#
#     4HR_ENTRIES  4HR_EXITS  TOTAL_4HR_FT
# 0     91.081340  81.647528    172.728868
# 1     86.979888  66.292006    153.271894
# 2     69.620118  64.018085    133.638202
# 3     54.538523  66.398802    120.937325
# 4     49.129187  59.938596    109.067783
# 5     55.314665  51.321343    106.636007
# 6     54.164777  40.923221     95.087998
# 7     42.901038  44.800051     87.701088
# 8     40.446429  33.801969     74.248397
# 9     37.380838  33.570060     70.950898
# 10    31.023069  38.522040     69.545109
# 11    29.339482  36.196750     65.536232
# 12    34.753660  29.179617     63.933277
# 13    29.988707  22.524491     52.513198
# 14    22.568902  25.792926     48.361828
# 15    20.498460  24.741294     45.239754
# 16    17.491714  20.266463     37.758177
# 17    20.137424  13.932087     34.069511

# %%
station_average_5am['FT_8HRS'] = station_average_5am.TOTAL_4HR_FT * 2
station_average_5am['FT_HOURLY'] = station_average_5am.FT_8HRS / 8
station_average_5am['ENTRIES_HOURLY'] = station_average_5am['4HR_ENTRIES'] / 4
station_average_5am['EXITS_HOURLY'] = station_average_5am['4HR_EXITS'] / 4

station_average_5am
# Out:
#             STATION       ENTRIES         EXITS  PREV_ENTRIES    PREV_EXITS  \
# 0    CHRISTOPHER ST  6.918423e+06  3.920482e+06  6.918332e+06  3.920400e+06
# 1    W 4 ST-WASH SQ  4.457847e+06  4.423881e+06  4.457760e+06  4.423814e+06
# 2    TIMES SQ-42 ST  1.046340e+08  8.399643e+07  1.046339e+08  8.399637e+07
# 3              1 AV  1.935302e+07  1.955901e+07  1.935301e+07  1.955896e+07
# 4              3 AV  4.581650e+06  4.877514e+06  4.581600e+06  4.877454e+06
# 5   34 ST-HERALD SQ  5.704223e+07  7.055146e+07  5.713493e+07  7.064119e+07
# 6    14 ST-UNION SQ  6.665773e+06  4.803903e+06  6.665719e+06  4.803862e+06
# 7    DELANCEY/ESSEX  3.937789e+06  3.438504e+06  3.937746e+06  3.438460e+06
# 8   42 ST-BRYANT PK  1.035379e+08  7.155369e+07  1.035378e+08  7.155366e+07
# 9          ASTOR PL  1.641917e+06  2.164673e+06  1.641880e+06  2.164639e+06
# 10   34 ST-PENN STA  2.005527e+07  2.181763e+07  2.005525e+07  2.181759e+07
# 11    EAST BROADWAY  1.325051e+07  3.623770e+06  1.325048e+07  3.623734e+06
# 12            14 ST  7.257404e+07  5.533091e+07  7.257401e+07  5.533088e+07
# 13            23 ST  7.870375e+07  7.934580e+07  7.870372e+07  7.934578e+07
# 14            28 ST  3.279532e+07  4.169194e+07  3.279530e+07  4.169191e+07
# 15  GRD CNTRL-42 ST  2.334105e+07  2.030227e+07  2.334103e+07  2.030224e+07
# 16            33 ST  1.673761e+07  3.250957e+06  1.673760e+07  3.250937e+06
# 17  34 ST-HUDSON YD  7.699112e+05  7.476266e+05  7.698910e+05  7.476127e+05
#
#     4HR_ENTRIES  4HR_EXITS  TOTAL_4HR_FT     FT_8HRS  FT_HOURLY  \
# 0     91.081340  81.647528    172.728868  345.457735  43.182217
# 1     86.979888  66.292006    153.271894  306.543788  38.317974
# 2     69.620118  64.018085    133.638202  267.276404  33.409551
# 3     54.538523  66.398802    120.937325  241.874651  30.234331
# 4     49.129187  59.938596    109.067783  218.135566  27.266946
# 5     55.314665  51.321343    106.636007  213.272015  26.659002
# 6     54.164777  40.923221     95.087998  190.175996  23.772000
# 7     42.901038  44.800051     87.701088  175.402177  21.925272
# 8     40.446429  33.801969     74.248397  148.496795  18.562099
# 9     37.380838  33.570060     70.950898  141.901796  17.737725
# 10    31.023069  38.522040     69.545109  139.090218  17.386277
# 11    29.339482  36.196750     65.536232  131.072464  16.384058
# 12    34.753660  29.179617     63.933277  127.866554  15.983319
# 13    29.988707  22.524491     52.513198  105.026395  13.128299
# 14    22.568902  25.792926     48.361828   96.723655  12.090457
# 15    20.498460  24.741294     45.239754   90.479507  11.309938
# 16    17.491714  20.266463     37.758177   75.516354   9.439544
# 17    20.137424  13.932087     34.069511   68.139022   8.517378
#
#     ENTRIES_HOURLY  EXITS_HOURLY
# 0        22.770335     20.411882
# 1        21.744972     16.573002
# 2        17.405029     16.004521
# 3        13.634631     16.599701
# 4        12.282297     14.984649
# 5        13.828666     12.830336
# 6        13.541194     10.230805
# 7        10.725259     11.200013
# 8        10.111607      8.450492
# 9         9.345210      8.392515
# 10        7.755767      9.630510
# 11        7.334870      9.049188
# 12        8.688415      7.294904
# 13        7.497177      5.631123
# 14        5.642225      6.448231
# 15        5.124615      6.185323
# 16        4.372928      5.066616
# 17        5.034356      3.483022

# %%
# importing MatPlot

import matplotlib.pyplot as plt

# %%
#plotting a bar graph showing the foot_traffic of all stations in comparison to each other
plt.bar(station_average_5am.STATION, station_average_5am.FT_HOURLY)
plt.xticks(rotation = 80)
plt.title("Late Night Total Foot Traffic", fontsize = 12, color="b")
# Out:
# Text(0.5, 1.0, 'Late Night Total Foot Traffic')

# %%
import seaborn as sns

# %%
avg = station_average_5am[['STATION', 'ENTRIES_HOURLY', 'EXITS_HOURLY', 'FT_HOURLY']].groupby(['STATION']).mean()
sns.heatmap(data = avg,
            cmap = 'Blues',
            annot = True)
# Out:
# <AxesSubplot:ylabel='STATION'>

# %%
pizza_daily
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  20:00:00  10037797
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS  4HR_ENTRIES  \
# 1       12611581  07/17/2021    10037293.0  12611537.0         30.0
# 2       12611642  07/17/2021    10037323.0  12611581.0         33.0
# 3       12611973  07/17/2021    10037356.0  12611642.0        106.0
# 4       12612370  07/17/2021    10037462.0  12611973.0        153.0
# 5       12612768  07/17/2021    10037615.0  12612370.0        182.0
# ...          ...         ...           ...         ...          ...
# 422672       222  10/28/2021           1.0       221.0          0.0
# 422673       222  10/29/2021           1.0       222.0          0.0
# 422674       223  10/29/2021           1.0       222.0          0.0
# 422675       223  10/29/2021           1.0       223.0          0.0
# 422676       223  10/29/2021           1.0       223.0          0.0
#
#         4HR_EXITS  TOTAL_4HR_FT
# 1            44.0          74.0
# 2            61.0          94.0
# 3           331.0         437.0
# 4           397.0         550.0
# 5           398.0         580.0
# ...           ...           ...
# 422672        1.0           1.0
# 422673        0.0           0.0
# 422674        1.0           1.0
# 422675        0.0           0.0
# 422676        0.0           0.0
#
# [422000 rows x 14 columns]

# %%
pizza_daily_time = pizza_daily[ (pizza_daily['TIME'] == '00:00:00') |
                                (pizza_daily['TIME'] == '04:00:00') |
                                (pizza_daily['TIME'] == '08:00:00') |
                                (pizza_daily['TIME'] == '12:00:00') |
                                (pizza_daily['TIME'] == '16:00:00') |
                                (pizza_daily['TIME'] == '20:00:00') 
                              ]

pizza_daily_time
# Out:
#          C/A  UNIT       SCP          STATION        DATE      TIME   ENTRIES  \
# 1       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  04:00:00  10037323
# 2       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  08:00:00  10037356
# 3       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  12:00:00  10037462
# 4       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  16:00:00  10037615
# 5       A021  R032  01-00-00   TIMES SQ-42 ST  07/17/2021  20:00:00  10037797
# ...      ...   ...       ...              ...         ...       ...       ...
# 422672  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  00:00:00         1
# 422673  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  04:00:00         1
# 422674  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  12:00:00         1
# 422675  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  16:00:00         1
# 422676  R551  R072  01-05-01  34 ST-HUDSON YD  10/29/2021  20:00:00         1
#
#            EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS  4HR_ENTRIES  \
# 1       12611581  07/17/2021    10037293.0  12611537.0         30.0
# 2       12611642  07/17/2021    10037323.0  12611581.0         33.0
# 3       12611973  07/17/2021    10037356.0  12611642.0        106.0
# 4       12612370  07/17/2021    10037462.0  12611973.0        153.0
# 5       12612768  07/17/2021    10037615.0  12612370.0        182.0
# ...          ...         ...           ...         ...          ...
# 422672       222  10/28/2021           1.0       221.0          0.0
# 422673       222  10/29/2021           1.0       222.0          0.0
# 422674       223  10/29/2021           1.0       222.0          0.0
# 422675       223  10/29/2021           1.0       223.0          0.0
# 422676       223  10/29/2021           1.0       223.0          0.0
#
#         4HR_EXITS  TOTAL_4HR_FT
# 1            44.0          74.0
# 2            61.0          94.0
# 3           331.0         437.0
# 4           397.0         550.0
# 5           398.0         580.0
# ...           ...           ...
# 422672        1.0           1.0
# 422673        0.0           0.0
# 422674        1.0           1.0
# 422675        0.0           0.0
# 422676        0.0           0.0
#
# [249556 rows x 14 columns]

# %%
by_time = pizza_daily_time.groupby(['TIME']).TOTAL_4HR_FT.mean().reset_index()

by_time
# Out:
#        TIME  TOTAL_4HR_FT
# 0  00:00:00    140.872701
# 1  04:00:00     27.146326
# 2  08:00:00    101.204305
# 3  12:00:00    276.748889
# 4  16:00:00    284.429655
# 5  20:00:00    364.946588

# %%
import numpy as np

plt.figure(figsize=(10,5))
plt.plot(by_time['TIME'], by_time['TOTAL_4HR_FT'])

plt.xlabel("Times per day (4hr block)")
plt.ylabel("Average Foot Traffic (All Stations)")
plt.xticks(np.arange(6), ['8pm-12am', '12am-4am', '4am-8am', '8am-12pm', '12pm-4pm', '4pm-8pm'], rotation = 0)
plt.title('Average Foot Traffic By 4hr Time Blocks')
# Out:
# Text(0.5, 1.0, 'Average Foot Traffic By 4hr Time Blocks')

# %%
b = np.random.uniform(size=(100,3))
b.shape
# Out:
# (100, 3)

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])
